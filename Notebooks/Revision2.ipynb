# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel('S3 Table Observed mean phenotype values.xlsx', header = 1).columns
# Out:
# Index(['accession_name', 'Root_weight', 'Shoot_weight', 'Root_length',
#        'Shoot_length', 'Root_Na+', 'Root_K+', 'Shoot_Na+', 'Shoot_K+',
#        'Chlorophyll_A', 'Chlorophyll_B', 'Stress_Root_weight',
#        'Stress_Shoot_weight', 'Stress_Root_length', 'Stress_Shoot_length',
#        'Stress_Root_Na+', 'Stress_Root_K+', 'Stress_Shoot_Na+',
#        'Stress_Shoot_K+', 'SES', 'Stress_Chlorophyll_A',
#        'Stress_Chlorophyll_B', 'Root_thickness', 'Shoot_thickness',
#        'Stress_Root_thickness', 'Stress_Shoot_thickness', 'Lost_Root_weight',
#        'Lost_Shoot_weight', 'Lost_Root_length', 'Lost_Shoot_length',
#        'Lost_Root_thickness', 'Lost_Shoot_thickness', 'Lost_Chlorophyll_A',
#        'Lost_Chlorophyll_B'],
#       dtype='object')

# %%
t = pd.read_excel('S3 Table Observed mean phenotype values.xlsx', header = 1)[['accession_name', 'Shoot_weight', 'Chlorophyll_A',
                                                                          'Stress_Shoot_weight', 'Stress_Chlorophyll_A']]

# %%
t.iloc[:,[1,3]].plot(kind = 'kde')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>

# %%
t.iloc[:,[2,4]].plot(kind = 'kde')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>

# %%
t.iloc[:,[1,2]].plot(kind = 'scatter', x = 'Shoot_weight', y = 'Chlorophyll_A')
# Out:
# <img src="data:image/png;base64,..." width="640">
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Shoot_weight', ylabel='Chlorophyll_A'>

# %%
t.iloc[:,[3,4]].plot(kind = 'scatter', x = 'Stress_Shoot_weight', y = 'Stress_Chlorophyll_A')
# Out:
# <img src="data:image/png;base64,..." width="640">
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Stress_Shoot_weight', ylabel='Stress_Chlorophyll_A'>

# %%
t

# %%
t['RC'] = t['Shoot_weight'] / t['Chlorophyll_A']
t['RS'] = t['Stress_Shoot_weight'] / t['Stress_Chlorophyll_A']

# %%
t.iloc[:,-2:].plot(kind = 'kde')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>

# %%
t[['accession_name', 'RC', 'RS']].to_clipboard(index = False)

# %%
pd.read_excel('S3 Table Observed mean phenotype values.xlsx', header = 1).columns
# Out:
# Index(['accession_name', 'Root_weight', 'Shoot_weight', 'Root_length',
#        'Shoot_length', 'Root_Na+', 'Root_K+', 'Shoot_Na+', 'Shoot_K+',
#        'Chlorophyll_A', 'Chlorophyll_B', 'Stress_Root_weight',
#        'Stress_Shoot_weight', 'Stress_Root_length', 'Stress_Shoot_length',
#        'Stress_Root_Na+', 'Stress_Root_K+', 'Stress_Shoot_Na+',
#        'Stress_Shoot_K+', 'SES', 'Stress_Chlorophyll_A',
#        'Stress_Chlorophyll_B', 'Root_thickness', 'Shoot_thickness',
#        'Stress_Root_thickness', 'Stress_Shoot_thickness', 'Lost_Root_weight',
#        'Lost_Shoot_weight', 'Lost_Root_length', 'Lost_Shoot_length',
#        'Lost_Root_thickness', 'Lost_Shoot_thickness', 'Lost_Chlorophyll_A',
#        'Lost_Chlorophyll_B'],
#       dtype='object')

# %%
y = pd.read_excel('S3 Table Observed mean phenotype values.xlsx', header = 1)

# %%
y['RRW'] = y['Stress_Root_weight'] / y['Root_weight']
y['RSW'] = y['Stress_Shoot_weight'] / y['Shoot_weight']
y['RRL'] = y['Stress_Root_length'] / y['Root_length']
y['RSL'] = y['Stress_Shoot_length'] / y['Shoot_length']
y['RCA'] = y['Stress_Chlorophyll_A'] / y['Chlorophyll_A']
y['RCB'] = y['Stress_Chlorophyll_B'] / y['Chlorophyll_B']
y['RRT'] = y['Stress_Root_thickness'] / y['Root_thickness']
y['RST'] = y['Stress_Shoot_thickness'] / y['Shoot_thickness']

# %%
y.iloc[:,-8:].to_clipboard(index = False)

# %%
pd.merge(pd.read_excel('S3 Table Observed mean phenotype values.xlsx', header = 1), pd.read_csv('../../../test.csv')).to_csv('S3.csv', index = False)

# %%
x = pd.read_clipboard()

# %%
x2 = pd.merge(pd.read_clipboard(), x)

# %%
x2.sort_values('SES').to_clipboard()
